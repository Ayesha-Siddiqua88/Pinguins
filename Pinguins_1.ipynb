# %%
import os
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("penguins_info.csv")
df
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  \
# ...

# %%
df.head()
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  11/11/2007
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  11/11/2007
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  11/16/2007
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  11/16/2007
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  11/16/2007
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  334 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
# ...

# %%
numcol=[]
catcol=[]

for col in df.columns:
    if df[col].dtype=='O':
        catcol.append(col)
    else:
        numcol.append(col)

# %%
print("list of numerical columns:",numcol)
print("list of categorical columns:",catcol)
# Out:
# list of numerical columns: ['Sample Number', 'Culmen Length (mm)', 'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)']
# list of categorical columns: ['studyName', 'Species', 'Region', 'Island', 'Stage', 'Individual ID', 'Clutch Completion', 'Date Egg', 'Sex', 'Comments']

# %% [markdown]
# # ***Descriptive Analysis***

# %%
df.describe(include="all")
# Out:
#        studyName  Sample Number                              Species  Region  \
# count        344     344.000000                                  344     344
# unique         3            NaN                                    3       1
# top      PAL0910            NaN  Adelie Penguin (Pygoscelis adeliae)  Anvers
# freq         120            NaN                                  152     344
# mean         NaN      63.151163                                  NaN     NaN
# std          NaN      40.430199                                  NaN     NaN
# min          NaN       1.000000                                  NaN     NaN
# 25%          NaN      29.000000                                  NaN     NaN
# 50%          NaN      58.000000                                  NaN     NaN
# 75%          NaN      95.250000                                  NaN     NaN
# max          NaN     152.000000                                  NaN     NaN
#
# ...

# %%
df[numcol].describe()
# Out:
#        Sample Number  Culmen Length (mm)  Culmen Depth (mm)  \
# count     344.000000          342.000000         342.000000
# mean       63.151163           43.921930          17.151170
# std        40.430199            5.459584           1.974793
# min         1.000000           32.100000          13.100000
# 25%        29.000000           39.225000          15.600000
# 50%        58.000000           44.450000          17.300000
# 75%        95.250000           48.500000          18.700000
# max       152.000000           59.600000          21.500000
#
#        Flipper Length (mm)  Body Mass (g)  Delta 15 N (o/oo)  \
# count           342.000000     342.000000         330.000000
# mean            200.915205    4201.754386           8.733382
# std              14.061714     801.954536           0.551770
# min             172.000000    2700.000000           7.632200
# 25%             190.000000    3550.000000           8.299890
# ...

# %%
df[catcol].describe().T
# Out:
#                   count unique                                    top freq
# studyName           344      3                                PAL0910  120
# Species             344      3    Adelie Penguin (Pygoscelis adeliae)  152
# Region              344      1                                 Anvers  344
# Island              344      3                                 Biscoe  168
# Stage               344      1                     Adult, 1 Egg Stage  344
# Individual ID       344    190                                  N61A2    3
# Clutch Completion   344      2                                    Yes  308
# Date Egg            344     50                             11/27/2007   18
# Sex                 334      3                                   MALE  168
# Comments             26      7  Nest never observed with full clutch.   13

# %%
# it is important to have more than one unique value in data analysis
# therefore the columns with one unique(no variation) can be removed
# also if more than half or 50% of the count is unique value then this variation is also not preferred in data analysis
# the column with much variation is also removed

# %% [markdown]
# # Missing Value Analysis

# %%
#in no-null count we see numbers are all not 344
# some of them are 342, 334 that is because the rest of the values are missing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Culmen Length (mm)   342 non-null    float64
#  10  Culmen Depth (mm)    342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  334 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
# ...

# %%
# this will give us the number of fields are missing
# in comments more than 50% of fields are missing so the column is not req
df.isna().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     10
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               318
# dtype: int64

# %%
#to get the % of missing values
df.isna().sum()/df.shape[0]*100
# Out:
# studyName               0.000000
# Sample Number           0.000000
# Species                 0.000000
# Region                  0.000000
# Island                  0.000000
# Stage                   0.000000
# Individual ID           0.000000
# Clutch Completion       0.000000
# Date Egg                0.000000
# Culmen Length (mm)      0.581395
# Culmen Depth (mm)       0.581395
# Flipper Length (mm)     0.581395
# Body Mass (g)           0.581395
# Sex                     2.906977
# Delta 15 N (o/oo)       4.069767
# Delta 13 C (o/oo)       3.779070
# Comments               92.441860
# dtype: float64

# %%
#rows where more than one value missing
df[df.isna().sum(axis=1)>1]
# Out:
#     studyName  Sample Number                                    Species  \
# 0     PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 3     PAL0708              4        Adelie Penguin (Pygoscelis adeliae)
# 8     PAL0708              9        Adelie Penguin (Pygoscelis adeliae)
# 11    PAL0708             12        Adelie Penguin (Pygoscelis adeliae)
# 12    PAL0708             13        Adelie Penguin (Pygoscelis adeliae)
# 13    PAL0708             14        Adelie Penguin (Pygoscelis adeliae)
# 15    PAL0708             16        Adelie Penguin (Pygoscelis adeliae)
# 39    PAL0708             40        Adelie Penguin (Pygoscelis adeliae)
# 41    PAL0708             42        Adelie Penguin (Pygoscelis adeliae)
# 46    PAL0708             47        Adelie Penguin (Pygoscelis adeliae)
# 47    PAL0708             48        Adelie Penguin (Pygoscelis adeliae)
# 212   PAL0910             61  Chinstrap penguin (Pygoscelis antarctica)
# ...

# %%
df[df.isna().sum(axis=1)>1].shape
# Out:
# (17, 17)

# %%
df[df.isna().sum(axis=1)>3]
# Out:
#     studyName  Sample Number                              Species  Region  \
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  \
# 3    Torgersen  Adult, 1 Egg Stage          N2A2               Yes
# 339     Biscoe  Adult, 1 Egg Stage         N38A2                No
#
#        Date Egg  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 3    11/16/2007                 NaN                NaN                  NaN
# 339   12/1/2009                 NaN                NaN                  NaN
#
#      Body Mass (g)  Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 3              NaN  NaN                NaN                NaN
# 339            NaN  NaN                NaN                NaN
#
#                Comments
# 3    Adult not sampled.
# 339                 NaN

# %%
df[df.isna().sum(axis=1)>3].shape
# Out:
# (2, 17)

# %%
sns.heatmap(df.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# # Check Duplicate, Repeated and Unknown

# %%
# if we have duplicate values we are going to drop them directly
#if we have repeated and unknown values, we cannot keep those values so
# so the best way to treat them is to convert them to missing values

# %%
# no duplicate values for this dataset but if were present then delete them
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Length: 344, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [studyName, Sample Number, Species, Region, Island, Stage, Individual ID, Clutch Completion, Date Egg, Culmen Length (mm), Culmen Depth (mm), Flipper Length (mm), Body Mass (g), Sex, Delta 15 N (o/oo), Delta 13 C (o/oo), Comments]
# Index: []

# %%
for i in catcol:
    print(i,"-----%NULL",(df[i].shape[0]-df[i].notnull().sum())/df[i].shape[0]*100)
    print(df[i].value_counts())
    print("\n")
# Out:
# studyName -----%NULL 0.0
# PAL0910    120
# PAL0809    114
# PAL0708    110
# Name: studyName, dtype: int64
#
#
# Species -----%NULL 0.0
# Adelie Penguin (Pygoscelis adeliae)          152
# Gentoo penguin (Pygoscelis papua)            124
# Chinstrap penguin (Pygoscelis antarctica)     68
# Name: Species, dtype: int64
#
#
# Region -----%NULL 0.0
# Anvers    344
# Name: Region, dtype: int64
#
#
# Island -----%NULL 0.0
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: Island, dtype: int64
#
#
# Stage -----%NULL 0.0
# Adult, 1 Egg Stage    344
# Name: Stage, dtype: int64
#
#
# Individual ID -----%NULL 0.0
# N61A2    3
# N29A2    3
# N22A1    3
# N22A2    3
# N23A1    3
#         ..
# N10A1    1
# N10A2    1
# N84A2    1
# N84A1    1
# N43A2    1
# Name: Individual ID, Length: 190, dtype: int64
#
#
# Clutch Completion -----%NULL 0.0
# Yes    308
# No      36
# Name: Clutch Completion, dtype: int64
#
#
# Date Egg -----%NULL 0.0
# 11/27/2007    18
# 11/9/2008     16
# ...

# %%
#changing .(dot) in sex as null value(missing value)
df['Sex']=df['Sex'].replace({".":np.nan})

# %%
#before the null value in sex was 10 now it is 11 as we replaced . with null
df.isna().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     11
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               318
# dtype: int64

# %% [markdown]
# # Handling missing values

# %%
df.isna().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     11
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               318
# dtype: int64

# %%
df.shape
# Out:
# (344, 17)

# %%
#dropping comments column so axis is 1
df_imp=df.drop(['Comments'], axis=1)
df_imp.shape

# #removing from categorical list as well
catcol.remove("Comments")

# %%
#removing the rows where more than 5 values missing
df[df.isna().sum(axis=1)>5]
# Out:
#     studyName  Sample Number                              Species  Region  \
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  \
# 3    Torgersen  Adult, 1 Egg Stage          N2A2               Yes
# 339     Biscoe  Adult, 1 Egg Stage         N38A2                No
#
#        Date Egg  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 3    11/16/2007                 NaN                NaN                  NaN
# 339   12/1/2009                 NaN                NaN                  NaN
#
#      Body Mass (g)  Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 3              NaN  NaN                NaN                NaN
# 339            NaN  NaN                NaN                NaN
#
#                Comments
# 3    Adult not sampled.
# 339                 NaN

# %%
df_imp=df_imp.drop([3,339],axis=0)
df_imp.shape
# Out:
# (342, 16)

# %%
#till here we dropped the 2 rows and a column
#but still there is missing data present
df.isna().sum()
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Culmen Length (mm)       2
# Culmen Depth (mm)        2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     11
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               318
# dtype: int64

# %%
#impot library that is used in data science for imputation,preprocessing
#median is more preferred as the data might be left or right skewed 
from sklearn.impute import SimpleImputer

imp_median=SimpleImputer(missing_values=np.nan,strategy='median')
imp_mode=SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
#creating dataframes 
df_num=pd.DataFrame(imp_median.fit_transform(df_imp[numcol]),columns=numcol)
df_cat=pd.DataFrame(imp_mode.fit_transform(df_imp[catcol]),columns=catcol)

# %%
#now no missing values
df_num.isna().sum()
# Out:
# Sample Number          0
# Culmen Length (mm)     0
# Culmen Depth (mm)      0
# Flipper Length (mm)    0
# Body Mass (g)          0
# Delta 15 N (o/oo)      0
# Delta 13 C (o/oo)      0
# dtype: int64

# %%
df_cat.isna().sum()
# Out:
# studyName            0
# Species              0
# Region               0
# Island               0
# Stage                0
# Individual ID        0
# Clutch Completion    0
# Date Egg             0
# Sex                  0
# dtype: int64

# %%
df_num.head()
# Out:
#    Sample Number  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0            1.0                39.1               18.7                181.0
# 1            2.0                39.5               17.4                186.0
# 2            3.0                40.3               18.0                195.0
# 3            5.0                36.7               19.3                193.0
# 4            6.0                39.3               20.6                190.0
#
#    Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# 0         3750.0           8.652405          -25.83352
# 1         3800.0           8.949560          -24.69454
# 2         3250.0           8.368210          -25.33302
# 3         3450.0           8.766510          -25.32426
# 4         3650.0           8.664960          -25.29805

# %%
df_cat.head()
# Out:
#   studyName                              Species  Region     Island  \
# 0   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4   PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
#
#                 Stage Individual ID Clutch Completion    Date Egg     Sex
# 0  Adult, 1 Egg Stage          N1A1               Yes  11/11/2007    MALE
# 1  Adult, 1 Egg Stage          N1A2               Yes  11/11/2007  FEMALE
# 2  Adult, 1 Egg Stage          N2A1               Yes  11/16/2007  FEMALE
# 3  Adult, 1 Egg Stage          N3A1               Yes  11/16/2007  FEMALE
# 4  Adult, 1 Egg Stage          N3A2               Yes  11/16/2007    MALE

# %%
#creating the dataframe back
df_imp=pd.concat([df_num,df_cat],axis=1)

# %%
df_imp.isna().sum()
# Out:
# Sample Number          0
# Culmen Length (mm)     0
# Culmen Depth (mm)      0
# Flipper Length (mm)    0
# Body Mass (g)          0
# Delta 15 N (o/oo)      0
# Delta 13 C (o/oo)      0
# studyName              0
# Species                0
# Region                 0
# Island                 0
# Stage                  0
# Individual ID          0
# Clutch Completion      0
# Date Egg               0
# Sex                    0
# dtype: int64

# %% [markdown]
# # Outlier Analysis

# %%
df.boxplot();

# %%
for i in numcol:
    plt.figure()
    sns.boxplot(x=df[i])

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
print(((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR))).sum())
# Out:
# Body Mass (g)          0
# Clutch Completion      0
# Comments               0
# Culmen Depth (mm)      0
# Culmen Length (mm)     0
# Date Egg               0
# Delta 13 C (o/oo)      0
# Delta 15 N (o/oo)      0
# Flipper Length (mm)    0
# Individual ID          0
# Island                 0
# Region                 0
# Sample Number          0
# Sex                    0
# Species                0
# Stage                  0
# studyName              0
# dtype: int64
# C:\Users\siddi\AppData\Local\Temp\ipykernel_15320\3901925871.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Q1=df.quantile(0.25)
# ...

# %%
outnum=[]
for i in numcol:
    q1=df[i].quantile(0.25)
    q3=df[i].quantile(0.75)
    iqr=q3-q1
    
    upper_limit=q3+1.5*iqr
    lower_limit=q1-1.5*iqr
    outnum.append([i,q1,q3,iqr,lower_limit,upper_limit])
    
    df[i]=np.where(df[i]>upper_limit,upper_limit,
                  np.where(df[i]<lower_limit,lower_limit,
                          df[i]))

# %%
pd.DataFrame(outnum,columns=["variableName","Q1","Q3","IQR","lower_limit","upper_limit"])
# Out:
#           variableName           Q1           Q3          IQR  lower_limit  \
# 0        Sample Number    29.000000    95.250000    66.250000   -70.375000
# 1   Culmen Length (mm)    39.225000    48.500000     9.275000    25.312500
# 2    Culmen Depth (mm)    15.600000    18.700000     3.100000    10.950000
# 3  Flipper Length (mm)   190.000000   213.000000    23.000000   155.500000
# 4        Body Mass (g)  3550.000000  4750.000000  1200.000000  1750.000000
# 5    Delta 15 N (o/oo)     8.299890     9.172123     0.872232     6.991541
# 6    Delta 13 C (o/oo)   -26.320305   -25.062050     1.258255   -28.207687
#
#    upper_limit
# 0   194.625000
# 1    62.412500
# 2    23.350000
# 3   247.500000
# 4  6550.000000
# 5    10.480471
# 6   -23.174668

# %% [markdown]
# # Encoding Variables

# %%
df_imp[catcol]
# Out:
#     studyName                              Species  Region     Island  \
# 0     PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1     PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2     PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3     PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4     PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# ..        ...                                  ...     ...        ...
# 337   PAL0910    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 338   PAL0910    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 339   PAL0910    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 340   PAL0910    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 341   PAL0910    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
#
#                   Stage Individual ID Clutch Completion    Date Egg     Sex
# ...

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
# while labelencoder creates a sigle column
# if we have 11 unique values or variables present then it creates 10 unique columns for rest-onehotencoder

# %%
#we need to decide which should go under onehot and label encoder
#since individual has 190 unique values it will create 189 new columns
#in date egg has 50 unique values and it will create 49 new columns
#we dont want that many new column for analysis
#so choose less unique values to be onehotencoder and more unique values for labelencoder
for i in catcol:
    print(i,df[i].nunique())
# Out:
# studyName 3
# Species 3
# Region 1
# Island 3
# Stage 1
# Individual ID 190
# Clutch Completion 2
# Date Egg 50
# Sex 2

# %%
#how we do labelencoding
le=LabelEncoder()
for i in ["Individual ID","Date Egg"]:
    df_imp[i]=le.fit_transform(df_imp[i])

# %%
#we see the individual id and date egg with variables is now given numerical values
df_imp[catcol]
# Out:
#     studyName                              Species  Region     Island  \
# 0     PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 1     PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 2     PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 3     PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# 4     PAL0708  Adelie Penguin (Pygoscelis adeliae)  Anvers  Torgersen
# ..        ...                                  ...     ...        ...
# 337   PAL0910    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 338   PAL0910    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 339   PAL0910    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 340   PAL0910    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
# 341   PAL0910    Gentoo penguin (Pygoscelis papua)  Anvers     Biscoe
#
#                   Stage  Individual ID Clutch Completion  Date Egg     Sex
# ...

# %%
for i in["studyName","Species","Region","Island","Stage","Clutch Completion","Sex"]:
    y=pd.get_dummies(df_imp[i], prefix=i)
    df_imp=pd.concat([df_imp,y], axis=1)

# %%
df_imp.head()
# Out:
#    Sample Number  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0            1.0                39.1               18.7                181.0
# 1            2.0                39.5               17.4                186.0
# 2            3.0                40.3               18.0                195.0
# 3            5.0                36.7               19.3                193.0
# 4            6.0                39.3               20.6                190.0
#
#    Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo) studyName  \
# 0         3750.0           8.652405          -25.83352   PAL0708
# 1         3800.0           8.949560          -24.69454   PAL0708
# 2         3250.0           8.368210          -25.33302   PAL0708
# 3         3450.0           8.766510          -25.32426   PAL0708
# 4         3650.0           8.664960          -25.29805   PAL0708
#
#                                Species  Region  ...  \
# 0  Adelie Penguin (Pygoscelis adeliae)  Anvers  ...
# ...

# %%
df_imp.columns
# Out:
# Index(['Sample Number', 'Culmen Length (mm)', 'Culmen Depth (mm)',
#        'Flipper Length (mm)', 'Body Mass (g)', 'Delta 15 N (o/oo)',
#        'Delta 13 C (o/oo)', 'studyName', 'Species', 'Region', 'Island',
#        'Stage', 'Individual ID', 'Clutch Completion', 'Date Egg', 'Sex',
#        'studyName_PAL0708', 'studyName_PAL0809', 'studyName_PAL0910',
#        'Species_Adelie Penguin (Pygoscelis adeliae)',
#        'Species_Chinstrap penguin (Pygoscelis antarctica)',
#        'Species_Gentoo penguin (Pygoscelis papua)', 'Region_Anvers',
#        'Island_Biscoe', 'Island_Dream', 'Island_Torgersen',
#        'Stage_Adult, 1 Egg Stage', 'Clutch Completion_No',
#        'Clutch Completion_Yes', 'Sex_FEMALE', 'Sex_MALE'],
#       dtype='object')

# %%
colsubset=[i for i in df_imp.columns if "Sex" in i]

# %%
df_imp[colsubset]
# Out:
#         Sex  Sex_FEMALE  Sex_MALE
# 0      MALE           0         1
# 1    FEMALE           1         0
# 2    FEMALE           1         0
# 3    FEMALE           1         0
# 4      MALE           0         1
# ..      ...         ...       ...
# 337  FEMALE           1         0
# 338  FEMALE           1         0
# 339    MALE           0         1
# 340  FEMALE           1         0
# 341    MALE           0         1
#
# [342 rows x 3 columns]

# %%
df_imp=df_imp.drop(["studyName","Species","Region","Island","Stage","Clutch Completion","Sex"],axis=1)
df_imp.head()
# Out:
#    Sample Number  Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# 0            1.0                39.1               18.7                181.0
# 1            2.0                39.5               17.4                186.0
# 2            3.0                40.3               18.0                195.0
# 3            5.0                36.7               19.3                193.0
# 4            6.0                39.3               20.6                190.0
#
#    Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)  Individual ID  \
# 0         3750.0           8.652405          -25.83352             22
# 1         3800.0           8.949560          -24.69454             23
# 2         3250.0           8.368210          -25.33302             44
# 3         3450.0           8.766510          -25.32426             66
# 4         3650.0           8.664960          -25.29805             67
#
#    Date Egg  studyName_PAL0708  ...  \
# 0         3                  1  ...
# ...

# %%
#from sklearn.preprocessing import OneHotEncoder
#encoder=OneHotEncoder()
# onehot=encoder.fit_transform(df)
#print(onehot.shape)
#the columns will increase to 1476
